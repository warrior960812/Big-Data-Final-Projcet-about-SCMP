# %%
import pandas
df1=pandas.read_csv("scmp201504.csv").sort_values(by="dates",ascending=True)
df2=pandas.read_csv("scmp201505.csv").sort_values(by="dates",ascending=True)
df3=pandas.read_csv("scmp2015.csv").sort_values(by="dates",ascending=True)
df4=pandas.read_csv("scmp201509.csv").sort_values(by="dates",ascending=True)
df5=pandas.read_csv("scmp201512.csv").sort_values(by="dates",ascending=True)

# %%
pd2015=pandas.concat([df1,df2,df3,df4,df5], ignore_index=True)

# %%
pd2015
# Out:
#        Unnamed: 0                                              title  \
# 0             0.0  China issues rules on bank deposit insurance s...
# 1            35.0  Green roofs look better while saving money and...
# 2            36.0  Email lifts lid on discord at top of Hong Kong...
# 3            37.0  Hong Kong student makes surprise discovery of ...
# 4            38.0              Worker dies after lift shaft accident
# 5            39.0  Agency chief who recruited 200 maids accuses M...
# 6            40.0  Mainland China's LeTV plans to spend big to ex...
# 7            41.0  Residency ruling in Cathay pilot's Canadian di...
# 8            42.0  Historic Hong Kong shops and cafes close to ma...
# 9            43.0  Hong Kong lawmakers grill police over purchase...
# 10           44.0  Hong Kong Urban Renewal Authority agrees to su...
# 11           45.0  Hong Kong youngsters tested to see how competi...
# 12           46.0  Hong Kong's Urban Renewal Authority stuck in c...
# 13           47.0                                Bouquets for a star
# 14           48.0  Hong Kong Hospital Authority set to shake up h...
# 15           49.0  Hong Kong Occupy leader Benny Tai allowed to r...
# 16           50.0  Mainland power boost plan shelved amid reliabi...
# 17           51.0  Privacy watchdog issues guidelines on use of d...
# 18           52.0  How business can benefit by making use of big ...
# 19           53.0                  As the Gods Will (III) (Japanese)
# 20           54.0                                        The Planner
# 21           55.0                                            Sky Blu
# 22           57.0  Purton has been standout as Moreira magic mesm...
# 23           58.0  China's record high property inventories seen ...
# 24           59.0                  Emperor wins site in Sham Shui Po
# 25           60.0  ING Real Estate Finance expects Asian outbound...
# 26           61.0  Tseung Kwan O becomes property battleground wi...
# 27           62.0  Disruptive innovation to shake up office marke...
# 28           63.0  Robert Scholten explains how on-the-ground fin...
# 29           64.0  Shopping centre glut to hit mainland China cit...
# ...           ...                                                ...
# 18389      1073.0                                       Zero to hero
# 18390      1063.0  Xi calls on Politburo to follow his lead: Pres...
# 18391      1074.0  Cricket: Injured McCullum may miss third Sri L...
# 18392      1075.0  UPDATE 1-NFL-Eagles dump head coach Kelly afte...
# 18393      1076.0  Hong Kong take on Guangdong in Interport for m...
# 18394      1071.0                                        TRACK STARS
# 18395      1062.0  Ex-premier Li Peng's daughter quits top power job
# 18396      1049.0  A trip back in time: when a one-hour ride to G...
# 18397      1060.0  50 minutes to Guangzhou: New express rail stat...
# 18398      1046.0  Big team effort: Surprise Hong Kong district c...
# 18399      1047.0  Our special-needs kids need more support, Hong...
# 18400      1048.0  Son on murder rap after top Hong Kong doctor s...
# 18401      1061.0  Back from the brink: Dozens of elderly Hongkon...
# 18402      1051.0                                   How you can give
# 18403      1052.0  Operation Santa Claus: AIA staff lap up raceco...
# 18404      1050.0  Hong Kong migrant worker unions slam property ...
# 18405      1054.0  Fears for flat prices amid 'oversupply' Furthe...
# 18406      1055.0               Female models added to CY's Facebook
# 18407      1056.0                                     Home reprieved
# 18408      1057.0  Xi earmarks his top brass for overhaul of PLA:...
# 18409      1058.0                                         CONTACT US
# 18410      1059.0  HK heading for unwanted options on working hou...
# 18411      1053.0  Pan-democrats reach out to Liberals on key dis...
# 18412      1083.0  Property scare: Hong Kong conglomerate speeds ...
# 18413      1078.0                   Chart of the day for December 30
# 18414      1079.0  Hong Kong and Chinese stock markets: technolog...
# 18415      1080.0  Hong Kong stock market poised to have worst ye...
# 18416      1081.0  Noble rating cut to 'junk' as commodities cont...
# 18417      1082.0  One Belt, One Road, One ZTE: Chinese telecoms ...
# 18418      1084.0  Shortage of warehouse space in Hong Kong likel...
#
#                                 byline         dates
# 0                         Ren, Daniel.      1-Apr-15
# 1                                  NaN      1-Apr-15
# 2         Wong, Olga; Fung, Fanny W Y.      1-Apr-15
# 3                            Yu, Alan.      1-Apr-15
# 4                                  NaN      1-Apr-15
# 5                          Siu, Phila.      1-Apr-15
# 6                          Siu, Phila.      1-Apr-15
# 7                        Chan, Thomas.      1-Apr-15
# 8                       Ngo, Jennifer.      1-Apr-15
# 9                        Chan, Samuel.      1-Apr-15
# 10                      Fanny WY Fung.      1-Apr-15
# 11                        Sung, Timmy.      1-Apr-15
# 12     Fung, Fanny W Y; Zhao, Shirley.      1-Apr-15
# 13                                 NaN      1-Apr-15
# 14                       Tsang, Emily.      1-Apr-15
# 15                          Ng, Joyce.      1-Apr-15
# 16                        Kao, Ernest.      1-Apr-15
# 17                     Kang-chung, Ng.      1-Apr-15
# 18                  Zavadszky, Andrea.      1-Apr-15
# 19                                 NaN      1-Apr-15
# 20                                 NaN      1-Apr-15
# 21                                 NaN      1-Apr-15
# 22                                 NaN      1-Apr-15
# 23                      Chiang, Langi.      1-Apr-15
# 24                                 NaN      1-Apr-15
# 25                          Li, Sandy.      1-Apr-15
# 26                          Li, Sandy.      1-Apr-15
# 27                      Andrew, Peter.      1-Apr-15
# 28                          Li, Sandy.      1-Apr-15
# 29                        Sito, Peggy.      1-Apr-15
# ...                                ...           ...
# 18389                              NaN   31 Dec 2015
# 18390                              NaN   31 Dec 2015
# 18391                              NaN   31 Dec 2015
# 18392                              NaN   31 Dec 2015
# 18393                              NaN   31 Dec 2015
# 18394                              NaN   31 Dec 2015
# 18395                              NaN   31 Dec 2015
# 18396                              NaN   31 Dec 2015
# 18397                              NaN   31 Dec 2015
# 18398                              NaN   31 Dec 2015
# 18399                              NaN   31 Dec 2015
# 18400                              NaN   31 Dec 2015
# 18401                              NaN   31 Dec 2015
# 18402                              NaN   31 Dec 2015
# 18403                              NaN   31 Dec 2015
# 18404                              NaN   31 Dec 2015
# 18405                              NaN   31 Dec 2015
# 18406                              NaN   31 Dec 2015
# 18407                              NaN   31 Dec 2015
# 18408                              NaN   31 Dec 2015
# 18409                              NaN   31 Dec 2015
# 18410                              NaN   31 Dec 2015
# 18411                              NaN   31 Dec 2015
# 18412                              NaN  31 Dec 2015.
# 18413                              NaN  31 Dec 2015.
# 18414                              NaN  31 Dec 2015.
# 18415                              NaN  31 Dec 2015.
# 18416                              NaN  31 Dec 2015.
# 18417                              NaN  31 Dec 2015.
# 18418                              NaN  31 Dec 2015.
#
# [18419 rows x 4 columns]
