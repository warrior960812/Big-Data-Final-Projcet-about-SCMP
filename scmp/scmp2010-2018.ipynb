# %%
import pandas

# %%
df1=pandas.read_csv("scmp2010.csv").sort_values(by="dates",ascending=True)
df2=pandas.read_csv("scmp2011.csv").sort_values(by="dates",ascending=True)
df3=pandas.read_csv("scmp2012.csv").sort_values(by="dates",ascending=True)
df4=pandas.read_csv("scmp2013.csv").sort_values(by="dates",ascending=True)
df5=pandas.read_csv("scmp2014.csv").sort_values(by="dates",ascending=True)
df6=pandas.read_csv("scmp2015.csv").sort_values(by="dates",ascending=True)
df7=pandas.read_csv("scmp2016.csv").sort_values(by="dates",ascending=True)
df8=pandas.read_csv("scmp2017.csv").sort_values(by="dates",ascending=True)
df9=pandas.read_csv("scmp2018.csv").sort_values(by="dates",ascending=True)

# %%
df=pandas.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9], ignore_index=True)

# %%
del df["Unnamed: 0"]

# %%
df
# Out:
#                                                     title  \
# 0                                           Good exposure
# 1       SFC bid to recoup all HK$1b from firm's IPO Bi...
# 2       Sudanese civil war risk has CNPC oilfields ove...
# 3       The taxi financing rip-off that is taking us a...
# 4                                           Announcements
# 5                                             April Fool!
# 6                               Banners move by Democrats
# 7       31 pupils among 78 held in raids on gang alleg...
# 8                 Mixed blessings from Zen's trip to Rome
# 9                                                  Events
# 10             Henderson blames sales delay on loan curbs
# 11                                          In Brief: [1]
# 12                                               In Brief
# 13           Insurers, firms argue over when Sars started
# 14      Settlement reached in suit over lawyer's death...
# ...

# %%
df.dropna(subset=['title'], how='all', inplace = True)
df
# Out:
#                                                     title  \
# 0                                           Good exposure
# 1       SFC bid to recoup all HK$1b from firm's IPO Bi...
# 2       Sudanese civil war risk has CNPC oilfields ove...
# 3       The taxi financing rip-off that is taking us a...
# 4                                           Announcements
# 5                                             April Fool!
# 6                               Banners move by Democrats
# 7       31 pupils among 78 held in raids on gang alleg...
# 8                 Mixed blessings from Zen's trip to Rome
# 9                                                  Events
# 10             Henderson blames sales delay on loan curbs
# 11                                          In Brief: [1]
# 12                                               In Brief
# 13           Insurers, firms argue over when Sars started
# 14      Settlement reached in suit over lawyer's death...
# ...
