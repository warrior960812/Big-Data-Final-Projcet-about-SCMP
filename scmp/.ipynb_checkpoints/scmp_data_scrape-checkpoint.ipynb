# %%
root_url='https://search-proquest-com.lib-ezproxy.hkbu.edu.hk/asianews/publication/26858/citation/6F63087B31B643A0PQ/12?accountid=11440'

# %%
from selenium import webdriver
import time
browser = webdriver.Chrome() 
browser.get(root_url)

# %%
SLEEP=4

# %%
month = [
    ['Jan','January'],
    ['Feb','February'],
    ['Mar','March'],
    ['Apr','April'],
    ['May','May'],
    ['Jun','June'],
    ['Jul','July'],
    ['Aug','August'],
    ['Sep','September'],
    ['Oct','October'],
    ['Nov','November'],
    ['Dec','December']
]

# %%
pages = []
for i in range(2010,2011):
    a = 'filterdecade2010-2019'
    b = "filteryear" + str(i) + "2010-2018"
    for n in ['02','03','04','05','06','07','08','09','10','11','12']:
        c = "filtermonth" + n + str(i)
        for m in range(1,32):
            d = "filterissueName" + str(month[int(n)-1][0]) + str(m) + ',' + str(i) + str(month[int(n)-1][1])
            a_page = [a,b,c,d]
            pages.append(a_page)
pages
# Out:
# [['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan1,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan2,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan3,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan4,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan5,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan6,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan7,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan8,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan9,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan10,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan11,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan12,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan13,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan14,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan15,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan16,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan17,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan18,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan19,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan20,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan21,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan22,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan23,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan24,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan25,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan26,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan27,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan28,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan29,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan30,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan31,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb1,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb2,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb3,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb4,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb5,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb6,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb7,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb8,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb9,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb10,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb11,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb12,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb13,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb14,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb15,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb16,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb17,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb18,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb19,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb20,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb21,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb22,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb23,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb24,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb25,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb26,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb27,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb28,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb29,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb30,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth022011',
#   'filterissueNameFeb31,2011February'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar1,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar2,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar3,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar4,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar5,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar6,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar7,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar8,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar9,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar10,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar11,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar12,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar13,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar14,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar15,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar16,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar17,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar18,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar19,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar20,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar21,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar22,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar23,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar24,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar25,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar26,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar27,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar28,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar29,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar30,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth032011',
#   'filterissueNameMar31,2011March'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr1,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr2,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr3,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr4,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr5,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr6,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr7,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr8,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr9,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr10,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr11,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr12,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr13,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr14,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr15,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr16,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr17,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr18,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr19,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr20,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr21,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr22,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr23,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr24,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr25,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr26,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr27,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr28,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr29,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr30,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth042011',
#   'filterissueNameApr31,2011April'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay1,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay2,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay3,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay4,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay5,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay6,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay7,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay8,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay9,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay10,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay11,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay12,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay13,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay14,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay15,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay16,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay17,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay18,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay19,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay20,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay21,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay22,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay23,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay24,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay25,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay26,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay27,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay28,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay29,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay30,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth052011',
#   'filterissueNameMay31,2011May'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun1,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun2,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun3,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun4,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun5,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun6,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun7,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun8,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun9,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun10,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun11,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun12,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun13,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun14,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun15,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun16,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun17,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun18,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun19,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun20,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun21,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun22,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun23,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun24,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun25,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun26,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun27,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun28,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun29,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun30,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth062011',
#   'filterissueNameJun31,2011June'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul1,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul2,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul3,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul4,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul5,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul6,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul7,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul8,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul9,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul10,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul11,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul12,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul13,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul14,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul15,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul16,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul17,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul18,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul19,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul20,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul21,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul22,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul23,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul24,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul25,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul26,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul27,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul28,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul29,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul30,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth072011',
#   'filterissueNameJul31,2011July'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug1,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug2,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug3,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug4,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug5,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug6,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug7,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug8,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug9,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug10,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug11,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug12,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug13,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug14,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug15,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug16,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug17,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug18,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug19,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug20,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug21,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug22,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug23,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug24,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug25,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug26,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug27,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug28,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug29,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug30,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth082011',
#   'filterissueNameAug31,2011August'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep1,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep2,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep3,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep4,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep5,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep6,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep7,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep8,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep9,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep10,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep11,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep12,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep13,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep14,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep15,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep16,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep17,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep18,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep19,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep20,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep21,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep22,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep23,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep24,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep25,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep26,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep27,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep28,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep29,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep30,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth092011',
#   'filterissueNameSep31,2011September'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct1,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct2,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct3,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct4,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct5,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct6,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct7,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct8,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct9,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct10,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct11,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct12,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct13,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct14,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct15,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct16,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct17,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct18,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct19,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct20,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct21,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct22,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct23,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct24,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct25,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct26,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct27,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct28,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct29,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct30,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth102011',
#   'filterissueNameOct31,2011October'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov1,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov2,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov3,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov4,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov5,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov6,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov7,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov8,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov9,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov10,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov11,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov12,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov13,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov14,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov15,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov16,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov17,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov18,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov19,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov20,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov21,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov22,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov23,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov24,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov25,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov26,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov27,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov28,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov29,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov30,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth112011',
#   'filterissueNameNov31,2011November'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec1,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec2,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec3,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec4,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec5,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec6,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec7,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec8,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec9,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec10,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec11,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec12,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec13,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec14,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec15,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec16,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec17,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec18,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec19,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec20,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec21,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec22,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec23,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec24,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec25,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec26,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec27,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec28,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec29,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec30,2011December'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth122011',
#   'filterissueNameDec31,2011December']]

# %%
def scrape_one_page():
    articles=browser.find_elements_by_class_name("resultItem")
    data=[]
    for article in articles:
        headline=article.find_element_by_class_name("truncatedResultsTitle").text
        byline=article.find_elements_by_class_name("titleAuthorETC")[0].text
        byline2=article.find_elements_by_class_name("titleAuthorETC")[1].text
        data.append((headline,byline,byline2,datestr))
    return data

# %%
all_data=[]
for page in pages:
    try:
        browser.get(root_url)
        time.sleep(SLEEP)
        for element in page:
            browser.find_element_by_id(element).click()
            time.sleep(SLEEP)
        datestr=page[-1]
        data=scrape_one_page()
        all_data.extend(data)
        nextpage=browser.find_element_by_css_selector("#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a")
        nextpage.click()
        datestr=page[-1]
        data=scrape_one_page()
        all_data.extend(data)
    except Exception as e:
        print("Failed on",page)
        print(e)
# Out:
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth012011', 'filterissueNameJan2,2011January']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameJan2,2011January"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth012011', 'filterissueNameJan7,2011January']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameJan7,2011January"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth012011', 'filterissueNameJan9,2011January']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filtermonth012011"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth012011', 'filterissueNameJan10,2011January']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameJan10,2011January"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth012011', 'filterissueNameJan16,2011January']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth012011', 'filterissueNameJan19,2011January']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filtermonth012011"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth012011', 'filterissueNameJan23,2011January']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth012011', 'filterissueNameJan30,2011January']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filteryear20112010-2018"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb3,2011February']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameFeb3,2011February"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb4,2011February']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameFeb4,2011February"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb5,2011February']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb6,2011February']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb10,2011February']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filteryear20112010-2018"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb13,2011February']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filtermonth022011"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb18,2011February']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filtermonth022011"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb20,2011February']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb23,2011February']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filteryear20112010-2018"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb27,2011February']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb28,2011February']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameFeb28,2011February"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb29,2011February']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameFeb29,2011February"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb30,2011February']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameFeb30,2011February"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth022011', 'filterissueNameFeb31,2011February']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameFeb31,2011February"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth032011', 'filterissueNameMar6,2011March']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth032011', 'filterissueNameMar13,2011March']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth032011', 'filterissueNameMar20,2011March']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth032011', 'filterissueNameMar27,2011March']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth032011', 'filterissueNameMar28,2011March']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filteryear20112010-2018"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth042011', 'filterissueNameApr3,2011April']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth042011', 'filterissueNameApr5,2011April']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filtermonth042011"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth042011', 'filterissueNameApr6,2011April']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameApr6,2011April"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth042011', 'filterissueNameApr10,2011April']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth042011', 'filterissueNameApr15,2011April']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameApr15,2011April"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth042011', 'filterissueNameApr17,2011April']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth042011', 'filterissueNameApr24,2011April']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth042011', 'filterissueNameApr26,2011April']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filteryear20112010-2018"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth042011', 'filterissueNameApr31,2011April']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameApr31,2011April"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth052011', 'filterissueNameMay1,2011May']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filtermonth052011"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth052011', 'filterissueNameMay5,2011May']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filteryear20112010-2018"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth052011', 'filterissueNameMay8,2011May']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filteryear20112010-2018"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth052011', 'filterissueNameMay13,2011May']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filtermonth052011"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth052011', 'filterissueNameMay15,2011May']
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20112010-2018', 'filtermonth052011', 'filterissueNameMay17,2011May']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameMay17,2011May"}
#   (Session info: chrome=70.0.3538.110)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.13.3 x86_64)

# %%
import pandas as pd

# %%
df=pd.DataFrame(all_data,columns=["title","byline","byline2","datestr"])
df

# %%
for i in range(len(df["datestr"])):
    df['datestr'][i] = df['datestr'][i].split('Name')[-1]

# %%
for i in range(len(df["byline2"])):
    df['byline2'][i] = df['byline2'][i].split(']')[-1]
df["byline2"]
for i in range(len(df["byline2"])):
    df["byline2"][i]=df["byline2"][i].split(":")[0]
df["byline2"]

# %%
del df["datestr"]
df.columns=["title","byline","dates"]
df

# %%
df.to_csv("scmp2011.csv",encoding='utf-8')
