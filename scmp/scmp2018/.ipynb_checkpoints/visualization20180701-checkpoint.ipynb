# %%
import pandas

# %%
df=pandas.read_csv("scmp2018.csv")

# %%
df[250:300]
# Out:
#      Unnamed: 0                                              title  byline  \
# 250        2632  Can China play the globalisation card to win '...     NaN
# 251        1210                                        WHO SAID IT     NaN
# 252        1217  Dementia sufferer, 61, loses her way and walks...     NaN
# 253        1216  Sweden using me as a pawn against Beijing: boo...     NaN
# 254        1215  Hands off the penguins, China tells its touris...     NaN
# 255        1214  China, US 'to resume comprehensive economic di...     NaN
# 256        1213  China's J-20 stealth fighter jet lines up for ...     NaN
# 257        1212  British banker Rurik Jutting fails to overturn...     NaN
# 258        1211  'They were locked in an embrace' - Hong Kong c...     NaN
# 259        1209  Opposition tactics hit public trust in key ins...     NaN
# 260        1198  Hungry for love, Hong Kong singles pay up for ...     NaN
# 261        1207  Hongkongers spend average of HK$2,200 on Valen...     NaN
# 262        1206                                   Lo on life, love     NaN
# 263        1205  How losing loved ones to cancer spurred a woma...     NaN
# 264        1204  On the march with ex-soldier for Hong Kong tou...     NaN
# 265        1203  Bright sparks on mission to educate Hong Kong'...     NaN
# 266        1202  Students mean business at young entrepreneur p...     NaN
# 267        1201  Laws to protect sex workers leave them vulnera...     NaN
# 268        1200  How this cute travelling frog conquered Hongko...     NaN
# 269        1199  Speed dating, Tinder and 'leftover women': the...     NaN
# 270        1219  Gang snatches HK$20 million in ambush on money...     NaN
# 271        1208  'We're watching you,' regulator warns Hong Kon...     NaN
# 272        1220  Hong Kong boss jailed for torturing domestic h...     NaN
# 273        1218  Experts insist flu vaccines are '66 per cent e...     NaN
# 274        1222  Troubled West Kowloon Cultural District to see...     NaN
# 275        1221  Spat over Cantonese opera theatre's grand open...     NaN
# 276        1244  From Coca-Cola to Cathay Pacific, Swire Pacifi...     NaN
# 277        1243  Chinese textile giant buys Swiss luxury brand ...     NaN
# 278        1242  China's long-heralded crude oil futures contra...     NaN
# 279        1241  Cathay Pacific and offshore marine business wi...     NaN
# 280        1240  China UnionPay rolls out cash incentives on in...     NaN
# 281        1245  Xi's war on shadow banking spills over, threat...     NaN
# 282        1238                 Chart of the day: Food for thought     NaN
# 283        1237  Chinese animation studio behind Kung Fu Panda ...     NaN
# 284        1236                                          No escape     NaN
# 285        1235  Vincent Ho and Clarissa Lyra triumph in Race o...     NaN
# 286        1239  China and Hong Kong shares tumble again amid g...     NaN
# 287        1233  Hong Kong teen Haroon Arshad the hero for Glad...     NaN
# 288        1232  Hong Kong's Ben Rimene capable of Johnny Sexto...     NaN
# 289        1231                                          Wish list     NaN
# 290        1230  How acupuncture helped Chinese and US research...     NaN
# 291        1229  HNA holds its own Communist Party congress to ...     NaN
# 292        1228  China tops global poll for faith in AI technol...     NaN
# 293        1227  China seeks 'healthy' ties with troubled Maldi...     NaN
# 294        1226  China says yuan no longer a one-way bet as cur...     NaN
# 295        1225  US President Donald Trump's plan for 5G networ...     NaN
# 296        1224  Reclamation has both a history and future in H...     NaN
# 297        1234  Roy Jones Jnr cruises to decision victory in f...     NaN
# 298        1223                         In one voice for the Games     NaN
# 299        3426                                  Hitting the beach     NaN
#
#          dates    datetime
# 250  10-Apr-18  2018-04-10
# 251  10-Feb-18  2018-02-10
# 252  10-Feb-18  2018-02-10
# 253  10-Feb-18  2018-02-10
# 254  10-Feb-18  2018-02-10
# 255  10-Feb-18  2018-02-10
# 256  10-Feb-18  2018-02-10
# 257  10-Feb-18  2018-02-10
# 258  10-Feb-18  2018-02-10
# 259  10-Feb-18  2018-02-10
# 260  10-Feb-18  2018-02-10
# 261  10-Feb-18  2018-02-10
# 262  10-Feb-18  2018-02-10
# 263  10-Feb-18  2018-02-10
# 264  10-Feb-18  2018-02-10
# 265  10-Feb-18  2018-02-10
# 266  10-Feb-18  2018-02-10
# 267  10-Feb-18  2018-02-10
# 268  10-Feb-18  2018-02-10
# 269  10-Feb-18  2018-02-10
# 270  10-Feb-18  2018-02-10
# 271  10-Feb-18  2018-02-10
# 272  10-Feb-18  2018-02-10
# 273  10-Feb-18  2018-02-10
# 274  10-Feb-18  2018-02-10
# 275  10-Feb-18  2018-02-10
# 276  10-Feb-18  2018-02-10
# 277  10-Feb-18  2018-02-10
# 278  10-Feb-18  2018-02-10
# 279  10-Feb-18  2018-02-10
# 280  10-Feb-18  2018-02-10
# 281  10-Feb-18  2018-02-10
# 282  10-Feb-18  2018-02-10
# 283  10-Feb-18  2018-02-10
# 284  10-Feb-18  2018-02-10
# 285  10-Feb-18  2018-02-10
# 286  10-Feb-18  2018-02-10
# 287  10-Feb-18  2018-02-10
# 288  10-Feb-18  2018-02-10
# 289  10-Feb-18  2018-02-10
# 290  10-Feb-18  2018-02-10
# 291  10-Feb-18  2018-02-10
# 292  10-Feb-18  2018-02-10
# 293  10-Feb-18  2018-02-10
# 294  10-Feb-18  2018-02-10
# 295  10-Feb-18  2018-02-10
# 296  10-Feb-18  2018-02-10
# 297  10-Feb-18  2018-02-10
# 298  10-Feb-18  2018-02-10
# 299  10-May-18  2018-05-10

# %%
dfc=df["datetime"]=="2018-07-01"
df0701=df[dfc]
df0701
# Out:
#       Unnamed: 0                                              title  byline  \
# 4775         851          Yes, these six brands really are Canadian     NaN
# 4776         881                                  the price of love     NaN
# 4777         880  Lonely hearts beware: when money talks, is it ...     NaN
# 4778         879                                        Up in smoke     NaN
# 4779         878  Su Bingtian 9.91 sprinting success smacks more...     NaN
# 4780         877  Searching for the Chinese Lionel Messi? Xi Jin...     NaN
# 4781         876  The woman on a mission to show how a 600-year-...     NaN
# 4782         875  Is the promotion of this Chinese aerospace tec...     NaN
# 4783         874                                     Drumming it up     NaN
# 4784         873  China urged to give foreign companies a fair c...     NaN
# 4785         872  China says industrial profits rose from 2.9 tr...     NaN
# 4786         871                                 PHOTOS OF THE WEEK     NaN
# 4787         869  Endless TSA debate in Hong Kong is just a symp...     NaN
# 4788         868  Carrie Lam's first year a positive change but ...     NaN
# 4789         867  Asian teams in soccer's World Cup show the way...     NaN
# 4790         870  Here's how to make Hong Kong homes affordable:...     NaN
# 4791         865  Innovation fund urged to invest in own project...     NaN
# 4792         853  First private property sale takes a hit after ...     NaN
# 4793         854  Number of people on honours list hits 10-year low     NaN
# 4794         855  There's no Chinese 'debt trap', says Myanmar m...     NaN
# 4795         866  Police smash secret Hong Kong triad command ce...     NaN
# 4796         857  Yes, India has a rape problem but is it really...     NaN
# 4797         858  Eighteen dead after coach collides with truck ...     NaN
# 4798         856                                          VIEWPOINT     NaN
# 4799         860  Guangzhou Airport expansion plans could see 30...     NaN
# 4800         861  How the China-US trade row might pave the way ...     NaN
# 4801         862  As pressure piles on leader Carrie Lam to fix ...     NaN
# 4802         863  Hong Kong amateur photographer's stunning snap...     NaN
# 4803         864  Hong Kong lawmaker released from prison after ...     NaN
# 4804         859  European businesses in China are 'hurting' fro...     NaN
# 4805         852                                   Back to barracks     NaN
#
#              dates    datetime
# 4775  01 July 2018  2018-07-01
# 4776  01 July 2018  2018-07-01
# 4777  01 July 2018  2018-07-01
# 4778  01 July 2018  2018-07-01
# 4779  01 July 2018  2018-07-01
# 4780  01 July 2018  2018-07-01
# 4781  01 July 2018  2018-07-01
# 4782  01 July 2018  2018-07-01
# 4783  01 July 2018  2018-07-01
# 4784  01 July 2018  2018-07-01
# 4785  01 July 2018  2018-07-01
# 4786  01 July 2018  2018-07-01
# 4787  01 July 2018  2018-07-01
# 4788  01 July 2018  2018-07-01
# 4789  01 July 2018  2018-07-01
# 4790  01 July 2018  2018-07-01
# 4791  01 July 2018  2018-07-01
# 4792  01 July 2018  2018-07-01
# 4793  01 July 2018  2018-07-01
# 4794  01 July 2018  2018-07-01
# 4795  01 July 2018  2018-07-01
# 4796  01 July 2018  2018-07-01
# 4797  01 July 2018  2018-07-01
# 4798  01 July 2018  2018-07-01
# 4799  01 July 2018  2018-07-01
# 4800  01 July 2018  2018-07-01
# 4801  01 July 2018  2018-07-01
# 4802  01 July 2018  2018-07-01
# 4803  01 July 2018  2018-07-01
# 4804  01 July 2018  2018-07-01
# 4805  01 July 2018  2018-07-01

# %%
df0701.describe()
# Out:
#        Unnamed: 0  byline
# count   31.000000     0.0
# mean   866.000000     NaN
# std      9.092121     NaN
# min    851.000000     NaN
# 25%    858.500000     NaN
# 50%    866.000000     NaN
# 75%    873.500000     NaN
# max    881.000000     NaN

# %%
titlelist=df0701["title"].tolist()

# %%
import pandas as pd
import matplotlib.pyplot as plt                          
from PIL import Image
from scipy.misc import imread 
import numpy as np 
import seaborn as sns
import jieba
import wordcloud
from pylab import mpl 
from wordcloud import WordCloud, ImageColorGenerator,STOPWORDS
import imageio
def stopwordslist(filepath):  
    stopwords = [line.strip() for line in open(filepath, 'r', encoding='utf-8').readlines()]  
    return stopwords 

def getText(txt):
    text=open(txt,"r").read() 
    text=text.lower()                 
    for ch in '`!@#~$%^&*()_+-=*/{}[];,./?<>':
        text=text.replace(ch," ")  
    return text

def remove_stopwords(words):
    processed_word_list = []
    for word in words:
        word = word.lower() # in case they arenet all lower cased
        if word not in stopwords:
            processed_word_list.append(word)
    return processed_word_list

# %%
def word_count(processed_word_list):
    word_count = pandas.Series(processed_word_list).value_counts().sort_values(ascending=False)[0:20]  
    fig = plt.figure(figsize=(16,8))  
    x = word_count.index.tolist()  
    y = word_count.values.tolist()  
    sns.barplot(x, y, palette="BuPu_r")  
    plt.title('SCMP Top20')  
    plt.ylabel('count')  
    sns.despine(bottom=True)  
    #plt.savefig('/Users/xuyucan/SCMP词频统计.png',dpi=400)  
    plt.show()

# %%
def tag_cloud(text):
    image = Image.open(r'./picture.jpg')
    graph = np.array(image)
    wc = WordCloud(mode='RGBA',background_color='white',max_words=2000,stopwords=stopwords,max_font_size=300,random_state=42,mask=graph)
    wc.generate(' '.join(text))
    img = imageio.imread(r"\users\xuwen\venv\test\ppp.jpg") 
    cloud_colors = wordcloud.ImageColorGenerator(np.array(img))
    cloud_colors.default_color = [0.6,0.6,0.6]
    wc.recolor(color_func=cloud_colors)
    #wc.to_file(r"/Users/xuyucan/SCMP_tagcloud.png") 
    plt.figure(figsize=(12,12))
    plt.imshow(wc.recolor(color_func=cloud_colors), interpolation='bilinear')
    plt.axis("off")
    plt.title('SCMP', loc='Center', fontsize=20)
    plt.show()
    return plt.show()

# %%
stopwords = stopwordslist('./stopwords.txt')
stopwords = set(stopwords)
test=getText('./title0701.txt')  
words=test.split()
processed_word_list = remove_stopwords(words)
word_count(processed_word_list)
tag_cloud(processed_word_list)
