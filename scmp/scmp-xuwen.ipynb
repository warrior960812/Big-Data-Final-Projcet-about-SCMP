# %%
root_url='https://search-proquest-com.lib-ezproxy.hkbu.edu.hk/asianews/publication/26858/citation/6F63087B31B643A0PQ/12?accountid=11440'

# %%
from selenium import webdriver
import time 
browser = webdriver.Chrome() #initiate webdriver
browser.get(root_url)

# %%
pages=[
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth022013","filterissueNameFeb10,2013February"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth022013","filterissueNameFeb11,2013February"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth042013","filterissueNameApr9,2013April"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth042013","filterissueNameApr6,2013April"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth042013","filterissueNameApr19,2013April"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth042013","filterissueNameApr27,2013April"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth052013","filterissueNameMay1,2013May"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth052013","filterissueNameMay9,2013May"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth062013","filterissueNameJun2,2013July"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth062013","filterissueNameJun4,2013July"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth072013","filterissueNameJun18,2013July"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth072013","filterissueNameJun21,2013July"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth082013","filterissueNameAug2,2013August"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth082013","filterissueNameAug21,2013August"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth092013","filterissueNameSep18,2013September"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth092013","filterissueNameSep20,2013September"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth092013","filterissueNameSep24,2013September"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth092013","filterissueNameSep25,2013September"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth102013","filterissueNameOct1,2013October"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth102013","filterissueNameOct11,2013October"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth102013","filterissueNameOct19,2013October"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth102013","filterissueNameOct21,2013October"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth102013","filterissueNameOct22,2013October"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth102013","filterissueNameOct27,2013October"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth112013","filterissueNameNov3,2013November"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth112013","filterissueNameNov7,2013November"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth112013","filterissueNameNov11,2013November"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth112013","filterissueNameNov24,2013November"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth112013","filterissueNameNov25,2013November"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth112013","filterissueNameNov20,2013November"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth122013","filterissueNameDec1,2013December"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth122013","filterissueNameDec2,2013December"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth122013","filterissueNameDec5,2013December"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth122013","filterissueNameDec11,2013December"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth122013","filterissueNameDec16,2013December"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth122013","filterissueNameDec10,2013December"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth122013","filterissueNameDec18,2013December"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth122013","filterissueNameDec21,2013December"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth122013","filterissueNameDec24,2013December"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth122013","filterissueNameDec25,2013December"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth122013","filterissueNameDec26,2013December"],
    ["filterdecade2010-2019","filteryear20132010-2018","filtermonth122013","filterissueNameDec28,2013December"],
]

# %%
def scrape_one_page():
    articles=browser.find_elements_by_class_name("resultItem")
    data=[]
    for article in articles:
        headline=article.find_element_by_class_name("truncatedResultsTitle").text
        byline=article.find_elements_by_class_name("titleAuthorETC")[0].text
        byline2=article.find_elements_by_class_name("titleAuthorETC")[1].text
        data.append((headline,byline,byline2,datestr))
    return data

# %% [markdown]
# ### 把上面需要用的代码放到def里来 ###

# %%
SLEEP=3
all_data=[]
for page in pages:
    try:
        browser.get(root_url)
        time.sleep(SLEEP)
        for element in page:
            browser.find_element_by_id(element).click()
            time.sleep(SLEEP)
        datestr=page[-1]
        data=scrape_one_page()
        all_data.extend(data)
        nextpage=browser.find_element_by_css_selector("#lor_container > div.pub_bottom_sort_by > nav > ul > li:nth-child(5) > a")
        nextpage.click() 
        datestr=page[-1]
        data=scrape_one_page()
        all_data.extend(data)
    except Exception as e:
        print("Failed on",page)
        print(e)
# Out:
# Failed on ['filterdecade2010-2019', 'filteryear20132010-2018', 'filtermonth022013', 'filterissueNameFeb10,2013February']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameFeb10,2013February"}
#   (Session info: chrome=69.0.3497.92)
#   (Driver info: chromedriver=2.43.600210 (68dcf5eebde37173d4027fa8635e332711d2874a),platform=Windows NT 10.0.17134 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20132010-2018', 'filtermonth022013', 'filterissueNameFeb11,2013February']
# Message: no such element: Unable to locate element: {"method":"id","selector":"filterissueNameFeb11,2013February"}
#   (Session info: chrome=69.0.3497.92)
#   (Driver info: chromedriver=2.43.600210 (68dcf5eebde37173d4027fa8635e332711d2874a),platform=Windows NT 10.0.17134 x86_64)
#
# Failed on ['filterdecade2010-2019', 'filteryear20132010-2018', 'filtermonth042013', 'filterissueNameApr6,2013April']
# ...

# %%
import pandas as pd 
df=pd.DataFrame(all_data,columns=["title","byline","byline2","datestr"])
df
# Out:
#                                                   title  \
# 0     16 hurt by runaway concrete mixer in Lam Tin D...
# 1     Huawei vows to fix US 'problems' As its profit...
# 2     Imperialbowl goes for record HK$74m Ceramics d...
# 3     Night trading off to slow start New index futu...
# 4     Optimism is growing for IPOs Market is static,...
# 5     Passenger boarding bridges back in action [Der...
# 6     Report details torture of women in labour camp...
# 7     Strike cuts cargo volume in half Vessels are s...
# 8     Why top bankers deserve to be paid huge salari...
# 9     Xi pledges level playing field for global inve...
# 10    2017 poll is not the 'last battle for democrac...
# 11    Alarms sound over local subway drive The push ...
# 12    Australia's prime minister in Beijing [Derived...
# 13    Buyers, have we got a deal for you! Those elig...
# 14                        Holy order [Derived headline]
# 15         In "Yunnan miner tries... [Derived headline]
# ...

# %%
for i in range(len(df["byline2"])):
    df['byline2'][i] = df['byline2'][i].split(']')[-1]
df["byline2"]
for i in range(len(df["byline2"])):
    df["byline2"][i]=df["byline2"][i].split(":")[0]
df["byline2"]
# Out:
# 0       09 Apr 2013
# 1       09 Apr 2013
# 2       09 Apr 2013
# 3       09 Apr 2013
# 4       09 Apr 2013
# 5       09 Apr 2013
# 6       09 Apr 2013
# 7       09 Apr 2013
# 8       09 Apr 2013
# 9       09 Apr 2013
# 10      09 Apr 2013
# 11      09 Apr 2013
# 12      09 Apr 2013
# 13      09 Apr 2013
# 14      09 Apr 2013
# 15      09 Apr 2013
# 16      09 Apr 2013
# 17      09 Apr 2013
# 18      09 Apr 2013
# 19      09 Apr 2013
# 20      09 Apr 2013
# 21      09 Apr 2013
# 22      09 Apr 2013
# 23      09 Apr 2013
# 24      09 Apr 2013
# 25      09 Apr 2013
# 26      09 Apr 2013
# 27      09 Apr 2013
# 28      09 Apr 2013
# 29      09 Apr 2013
#            ...
# 1398    28 Dec 2013
# 1399    28 Dec 2013
# 1400    28 Dec 2013
# 1401    28 Dec 2013
# 1402    28 Dec 2013
# 1403    28 Dec 2013
# 1404    28 Dec 2013
# 1405    28 Dec 2013
# 1406    28 Dec 2013
# 1407    28 Dec 2013
# 1408    28 Dec 2013
# 1409    28 Dec 2013
# 1410    28 Dec 2013
# 1411    28 Dec 2013
# ...

# %%
df
# Out:
#                                                   title  \
# 0     16 hurt by runaway concrete mixer in Lam Tin D...
# 1     Huawei vows to fix US 'problems' As its profit...
# 2     Imperialbowl goes for record HK$74m Ceramics d...
# 3     Night trading off to slow start New index futu...
# 4     Optimism is growing for IPOs Market is static,...
# 5     Passenger boarding bridges back in action [Der...
# 6     Report details torture of women in labour camp...
# 7     Strike cuts cargo volume in half Vessels are s...
# 8     Why top bankers deserve to be paid huge salari...
# 9     Xi pledges level playing field for global inve...
# 10    2017 poll is not the 'last battle for democrac...
# 11    Alarms sound over local subway drive The push ...
# 12    Australia's prime minister in Beijing [Derived...
# 13    Buyers, have we got a deal for you! Those elig...
# 14                        Holy order [Derived headline]
# 15         In "Yunnan miner tries... [Derived headline]
# ...

# %%
del df["datestr"]

# %%
df.columns=["title","byline","dates"]
df
# Out:
#                                                   title  \
# 0     16 hurt by runaway concrete mixer in Lam Tin D...
# 1     Huawei vows to fix US 'problems' As its profit...
# 2     Imperialbowl goes for record HK$74m Ceramics d...
# 3     Night trading off to slow start New index futu...
# 4     Optimism is growing for IPOs Market is static,...
# 5     Passenger boarding bridges back in action [Der...
# 6     Report details torture of women in labour camp...
# 7     Strike cuts cargo volume in half Vessels are s...
# 8     Why top bankers deserve to be paid huge salari...
# 9     Xi pledges level playing field for global inve...
# 10    2017 poll is not the 'last battle for democrac...
# 11    Alarms sound over local subway drive The push ...
# 12    Australia's prime minister in Beijing [Derived...
# 13    Buyers, have we got a deal for you! Those elig...
# 14                        Holy order [Derived headline]
# 15         In "Yunnan miner tries... [Derived headline]
# ...

# %%
df.to_csv('scmpxw2013g.csv', encoding='utf-8')

# %%
import csv
with open('scmpxw1201.csv','r') as f: # open CSV
    reader = csv.reader(f) # read CSV
    column2 = [row[1] for row in reader]
print(column2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-6487400dfc3c> in <module>()
#       1 import csv
# ----> 2 with open('scmpxw1201.csv','r') as f: # open CSV
#       3     reader = csv.reader(f) # read CSV
#       4     column2 = [row[1] for row in reader]
#       5 print(column2)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scmpxw1201.csv'

# %%
for i in '\s+\.\!\/_,$%^*(+\"\')]+|[+——()?:【】“”‘’！，。’':#把那些乱七八糟的符号都去掉）
        titlewords = [item.replace(i," ") for item in column2] 
titlewords

# %%
str=" ".join(titlewords)
str

# %%
import re
titlesplit=re.split(r'[ ]',str)

# %%
words_list = titlesplit #the list of words you have
dict_words_frequency={}
for n in words_list:
    dict_words_frequency[n]=words_list.count(n)
#dict_words_frequency
dict_words_frequency

# %%
filepath = './stopwords.txt'
stopwords = [line.strip() for line in open(filepath, 'r', encoding='utf-8').readlines()]

# %%
! pip install nltk

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords = stopwords.words('english')

# %%
import os
import pandas as pd



def read_txt(path): #read files and get content
    all_text = []
    for file in os.listdir(path):
        f=open(file,"r")
        contents= f.read()
        all_text.append(contents)
    all_words = "".join(all_text)
    #remove punctuation
    for ch in '\s+\.\!\/_,$%^*(+\"\')]+|[+——()?:【】“”‘’':
        words = all_words.replace(ch," ")
    return words

def stopwordslist(filepath):   #set stopwords
    stopwords = [line.strip() for line in open(filepath, 'r').readlines()]  
    return stopwords

def remove_stopwords(words): #remove stopwords
    processed_word_list = []
    for word in words:
        word = word.lower() # in case they are not all lower cased
        if word not in stopwords:
            processed_word_list.append(word)
    return processed_word_list

words = read_txt(r"C:\Users\xuwen\venv\test\Scripts\") #pass your own file path that include list of .txt
words = words.split()
stopwords = stopwordslist('./stopwords_eng.txt')
stopwords = set(stopwords)
processed_word_list = remove_stopwords(words)
word_count = pd.Series(processed_word_list).value_counts().sort_values(ascending=False)[0:15]

# %% [markdown]
# ### 把图表的head换了一个 ###

# %%
import pandas as pd

# %%
df=pd.read_csv("scmp2011.csv")
df20110701=df.loc[df["dates"]=="01 July 2011"]
#计算出2011年7月1日的数据  Reference:https://blog.csdn.net/htbeker/article/details/80332360#
len(df20110701)

# %%
len("df20110701")

# %%
df=pd.read_csv()

# %%
from dateutil.parser import parse

# %%
dt_1 = parse("19 Jan 2010")
print(dt_1)

# %%
for i in df["dates"]:
    df_i=parse(i)
    print(df_i)

# %%
from datetime import datetime
from dateutil import parser
import numpy

# %%
def parse_datetime(x):
    try:
        return parser.parse(x)
    except:
        return numpy.nan
df['datetime'] = df['dates'].apply(parse_datetime)

# %%
df['count'] = 1

# %%
df

# %%
df["byline"].value_counts()

# %%
df.set_index('datetime').resample('1d').aggregate('sum').plot()

# %%
def noauthors(t):
    return 'anonymous.' in str(t).lower()
df['nobylines'] = df['byline'].apply(noauthors)

# %%
def haveauthors(t):
    return not ( 'anonymous.' in str(t).lower())
df["havebylines"]=df["byline"].apply(haveauthors)

# %%
df.set_index('datetime').resample('1w').aggregate('sum').plot()

# %%
df.to_csv('scmp-xuwen.csv', encoding='utf-8')
