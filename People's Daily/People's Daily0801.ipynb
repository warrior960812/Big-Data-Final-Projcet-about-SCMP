# %%
root_url="https://search-proquest-com.lib-ezproxy.hkbu.edu.hk/asianews/publication/2032725/citation/21BC158E17A64F27PQ/4?accountid=11440"

# %%
from selenium import webdriver
browser = webdriver.Chrome()

# %%
browser.get(root_url)

# %%
browser.find_element_by_css_selector('#filteryear2018').click()

# %%
browser.find_element_by_css_selector('#filtermonth072018').click()

# %%
url=browser.find_element_by_id("filterissueNameJul1,2018August").get_attribute("href")

# %%
browser.get(url)

# %%
items = browser.find_elements_by_class_name('resultItem')

# %%
data = []
for item in items:
    title = item.find_element_by_class_name('truncatedResultsTitle').text
    titleAuthorETC0 = item.find_elements_by_class_name('titleAuthorETC')[0].text
    titleAuthorETC1 = item.find_elements_by_class_name('titleAuthorETC')[1].text
    data.append((title, titleAuthorETC0, titleAuthorETC1))

# %%
data
# Out:
# [('800 tourists, 30m yuan generated in seven months at tourism site in Liupanshui',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Aeromexico jetliner hit by wind gust after takeoff: official',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Aeromexico plane crashes in north Mexico, no deaths',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('China launches traceability management platform for NEV batteries',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('China opening wider to the world',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('China to accelerate launch of one-stop govt service platform',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('China, Malaysia willing to deepen friendly cooperation',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Chinese premier meets British foreign secretary',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Commentary: US Fed rate hike, stronger dollar aggravate global debt risk',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ("Commentary: US stands against economic globalization out of 'jealous' mentality",
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('CPC central committee holds symposium on economic work',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('CPC meeting stresses economic stability in H2, Party discipline',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Defense ministry holds reception to celebrate PLA founding anniversary',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Despondency disappears in Baichehe village',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ("Editorial: US' 4.1 % growth far from being trade war weapon",
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Editorial: Where the trade war goes is up to US',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ("EU-US trade truce can't hide deep divergence",
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Five things to do in Liupanshui, Guizhou province',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Government to help 120,000 Chinese veterans get jobs in 2018',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('I am a Xinjianger', '', "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Liushen Florida Water to hit African market',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Newly renovated Great Wall sections collapse in rain as ancient originals stand firm',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Op-ed: Protectionism must be tackled to bring orderly global trade back',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ("Op-ed: Xi's Middle East, Africa visit sets South-South cooperation on new journey",
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('PLA to end commercial services',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Positive outcomes still possible on suspended projects as Chinese FM Wang Yi heads to Malaysia: expert',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Serena Williams experiences crushing defeat in San Jose',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('South Africa to introduce new visa policies for Chinese tourists',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Starbucks sees rare fall in profits in China in 3rd quarter',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('State Council promises severe punishment on substandard vaccine making, vowing institutional safeguards for drug safety',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Substandard DPT vaccines from Wuhan an isolated case: regulator',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Trump says could talk with Iran "pretty soon"',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('US ports to fall into a direct victim of trade war',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ("Washington's investment in Indo-Pacific won't cripple Belt and Road",
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ("Xi requires resolute ending of military's paid services",
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Yangtze River Stories (8) Endangered Chinese sturgeons survive through artificial breeding',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ('Yangtze River Stories (9) Three Gorges Dam creates over 1.1 trillion kwh cumulative power: report',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018."),
#  ("Yunnan airline introduces 'occupying seat ticket'",
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2018.")]

# %%
import pandas as pd

# %%
df = pd.DataFrame(data, columns=['title', 'tae0', 'tae1'])
df['datestr'] = 'filterissueNameAug2,2018August'

# %%
df
# Out:
#                                                 title tae0  \
# 0   800 tourists, 30m yuan generated in seven mont...
# 1   Aeromexico jetliner hit by wind gust after tak...
# 2   Aeromexico plane crashes in north Mexico, no d...
# 3   China launches traceability management platfor...
# 4                    China opening wider to the world
# 5   China to accelerate launch of one-stop govt se...
# 6   China, Malaysia willing to deepen friendly coo...
# 7     Chinese premier meets British foreign secretary
# 8   Commentary: US Fed rate hike, stronger dollar ...
# 9   Commentary: US stands against economic globali...
# 10  CPC central committee holds symposium on econo...
# 11  CPC meeting stresses economic stability in H2,...
# 12  Defense ministry holds reception to celebrate ...
# 13         Despondency disappears in Baichehe village
# 14  Editorial: US' 4.1 % growth far from being tra...
# 15    Editorial: Where the trade war goes is up to US
# 16       EU-US trade truce can't hide deep divergence
# 17  Five things to do in Liupanshui, Guizhou province
# 18  Government to help 120,000 Chinese veterans ge...
# 19                                  I am a Xinjianger
# 20        Liushen Florida Water to hit African market
# 21  Newly renovated Great Wall sections collapse i...
# 22  Op-ed: Protectionism must be tackled to bring ...
# 23  Op-ed: Xi's Middle East, Africa visit sets Sou...
# 24                     PLA to end commercial services
# 25  Positive outcomes still possible on suspended ...
# 26  Serena Williams experiences crushing defeat in...
# 27  South Africa to introduce new visa policies fo...
# 28  Starbucks sees rare fall in profits in China i...
# 29  State Council promises severe punishment on su...
# 30  Substandard DPT vaccines from Wuhan an isolate...
# 31      Trump says could talk with Iran "pretty soon"
# 32  US ports to fall into a direct victim of trade...
# 33  Washington's investment in Indo-Pacific won't ...
# 34  Xi requires resolute ending of military's paid...
# 35  Yangtze River Stories (8) Endangered Chinese s...
# 36  Yangtze River Stories (9) Three Gorges Dam cre...
# 37  Yunnan airline introduces 'occupying seat ticket'
#
#                                              tae1  \
# 0   People's Daily; Beijing [Beijing]01 Aug 2018.
# 1   People's Daily; Beijing [Beijing]01 Aug 2018.
# 2   People's Daily; Beijing [Beijing]01 Aug 2018.
# 3   People's Daily; Beijing [Beijing]01 Aug 2018.
# 4   People's Daily; Beijing [Beijing]01 Aug 2018.
# 5   People's Daily; Beijing [Beijing]01 Aug 2018.
# 6   People's Daily; Beijing [Beijing]01 Aug 2018.
# 7   People's Daily; Beijing [Beijing]01 Aug 2018.
# 8   People's Daily; Beijing [Beijing]01 Aug 2018.
# 9   People's Daily; Beijing [Beijing]01 Aug 2018.
# 10  People's Daily; Beijing [Beijing]01 Aug 2018.
# 11  People's Daily; Beijing [Beijing]01 Aug 2018.
# 12  People's Daily; Beijing [Beijing]01 Aug 2018.
# 13  People's Daily; Beijing [Beijing]01 Aug 2018.
# 14  People's Daily; Beijing [Beijing]01 Aug 2018.
# 15  People's Daily; Beijing [Beijing]01 Aug 2018.
# 16  People's Daily; Beijing [Beijing]01 Aug 2018.
# 17  People's Daily; Beijing [Beijing]01 Aug 2018.
# 18  People's Daily; Beijing [Beijing]01 Aug 2018.
# 19  People's Daily; Beijing [Beijing]01 Aug 2018.
# 20  People's Daily; Beijing [Beijing]01 Aug 2018.
# 21  People's Daily; Beijing [Beijing]01 Aug 2018.
# 22  People's Daily; Beijing [Beijing]01 Aug 2018.
# 23  People's Daily; Beijing [Beijing]01 Aug 2018.
# 24  People's Daily; Beijing [Beijing]01 Aug 2018.
# 25  People's Daily; Beijing [Beijing]01 Aug 2018.
# 26  People's Daily; Beijing [Beijing]01 Aug 2018.
# 27  People's Daily; Beijing [Beijing]01 Aug 2018.
# 28  People's Daily; Beijing [Beijing]01 Aug 2018.
# 29  People's Daily; Beijing [Beijing]01 Aug 2018.
# 30  People's Daily; Beijing [Beijing]01 Aug 2018.
# 31  People's Daily; Beijing [Beijing]01 Aug 2018.
# 32  People's Daily; Beijing [Beijing]01 Aug 2018.
# 33  People's Daily; Beijing [Beijing]01 Aug 2018.
# 34  People's Daily; Beijing [Beijing]01 Aug 2018.
# 35  People's Daily; Beijing [Beijing]01 Aug 2018.
# 36  People's Daily; Beijing [Beijing]01 Aug 2018.
# 37  People's Daily; Beijing [Beijing]01 Aug 2018.
#
#                            datestr
# 0   filterissueNameAug2,2018August
# 1   filterissueNameAug2,2018August
# 2   filterissueNameAug2,2018August
# 3   filterissueNameAug2,2018August
# 4   filterissueNameAug2,2018August
# 5   filterissueNameAug2,2018August
# 6   filterissueNameAug2,2018August
# 7   filterissueNameAug2,2018August
# 8   filterissueNameAug2,2018August
# 9   filterissueNameAug2,2018August
# 10  filterissueNameAug2,2018August
# 11  filterissueNameAug2,2018August
# 12  filterissueNameAug2,2018August
# 13  filterissueNameAug2,2018August
# 14  filterissueNameAug2,2018August
# 15  filterissueNameAug2,2018August
# 16  filterissueNameAug2,2018August
# 17  filterissueNameAug2,2018August
# 18  filterissueNameAug2,2018August
# 19  filterissueNameAug2,2018August
# 20  filterissueNameAug2,2018August
# 21  filterissueNameAug2,2018August
# 22  filterissueNameAug2,2018August
# 23  filterissueNameAug2,2018August
# 24  filterissueNameAug2,2018August
# 25  filterissueNameAug2,2018August
# 26  filterissueNameAug2,2018August
# 27  filterissueNameAug2,2018August
# 28  filterissueNameAug2,2018August
# 29  filterissueNameAug2,2018August
# 30  filterissueNameAug2,2018August
# 31  filterissueNameAug2,2018August
# 32  filterissueNameAug2,2018August
# 33  filterissueNameAug2,2018August
# 34  filterissueNameAug2,2018August
# 35  filterissueNameAug2,2018August
# 36  filterissueNameAug2,2018August
# 37  filterissueNameAug2,2018August

# %%
titlewords=df["title"].tolist()
titlewords
str(titlewords)
splitwords=str(titlewords).split()

# %%
words_list = splitwords #the list of words you have
dict_words_frequency={}
for n in words_list:
    dict_words_frequency[n]=words_list.count(n)
#dict_words_frequency
dict_words_frequency
# Out:
# {"['800": 1,
#  'tourists,': 1,
#  '30m': 1,
#  'yuan': 1,
#  'generated': 1,
#  'in': 13,
#  'seven': 1,
#  'months': 1,
#  'at': 1,
#  'tourism': 1,
#  'site': 1,
#  "Liupanshui',": 1,
#  "'Aeromexico": 2,
#  'jetliner': 1,
#  'hit': 2,
#  'by': 1,
#  'wind': 1,
#  'gust': 1,
#  'after': 1,
#  'takeoff:': 1,
#  "official',": 1,
#  'plane': 1,
#  'crashes': 1,
#  'north': 1,
#  'Mexico,': 1,
#  'no': 1,
#  "deaths',": 1,
#  "'China": 3,
#  'launches': 1,
#  'traceability': 1,
#  'management': 1,
#  'platform': 1,
#  'for': 3,
#  'NEV': 1,
#  "batteries',": 1,
#  'opening': 1,
#  'wider': 1,
#  'to': 13,
#  'the': 2,
#  "world',": 1,
#  'accelerate': 1,
#  'launch': 1,
#  'of': 4,
#  'one-stop': 1,
#  'govt': 1,
#  'service': 1,
#  "platform',": 1,
#  "'China,": 1,
#  'Malaysia': 1,
#  'willing': 1,
#  'deepen': 1,
#  'friendly': 1,
#  "cooperation',": 1,
#  "'Chinese": 1,
#  'premier': 1,
#  'meets': 1,
#  'British': 1,
#  'foreign': 1,
#  "secretary',": 1,
#  "'Commentary:": 1,
#  'US': 2,
#  'Fed': 1,
#  'rate': 1,
#  'hike,': 1,
#  'stronger': 1,
#  'dollar': 1,
#  'aggravate': 1,
#  'global': 2,
#  'debt': 1,
#  "risk',": 1,
#  '"Commentary:': 1,
#  'stands': 1,
#  'against': 1,
#  'economic': 3,
#  'globalization': 1,
#  'out': 1,
#  "'jealous'": 1,
#  'mentality",': 1,
#  "'CPC": 2,
#  'central': 1,
#  'committee': 1,
#  'holds': 2,
#  'symposium': 1,
#  'on': 4,
#  "work',": 1,
#  'meeting': 1,
#  'stresses': 1,
#  'stability': 1,
#  'H2,': 1,
#  'Party': 1,
#  "discipline',": 1,
#  "'Defense": 1,
#  'ministry': 1,
#  'reception': 1,
#  'celebrate': 1,
#  'PLA': 1,
#  'founding': 1,
#  "anniversary',": 1,
#  "'Despondency": 1,
#  'disappears': 1,
#  'Baichehe': 1,
#  "village',": 1,
#  '"Editorial:': 1,
#  "US'": 1,
#  '4.1': 1,
#  '%': 1,
#  'growth': 1,
#  'far': 1,
#  'from': 2,
#  'being': 1,
#  'trade': 5,
#  'war': 2,
#  'weapon",': 1,
#  "'Editorial:": 1,
#  'Where': 1,
#  'goes': 1,
#  'is': 1,
#  'up': 1,
#  "US',": 1,
#  '"EU-US': 1,
#  'truce': 1,
#  "can't": 1,
#  'hide': 1,
#  'deep': 1,
#  'divergence",': 1,
#  "'Five": 1,
#  'things': 1,
#  'do': 1,
#  'Liupanshui,': 1,
#  'Guizhou': 1,
#  "province',": 1,
#  "'Government": 1,
#  'help': 1,
#  '120,000': 1,
#  'Chinese': 4,
#  'veterans': 1,
#  'get': 1,
#  'jobs': 1,
#  "2018',": 1,
#  "'I": 1,
#  'am': 1,
#  'a': 2,
#  "Xinjianger',": 1,
#  "'Liushen": 1,
#  'Florida': 1,
#  'Water': 1,
#  'African': 1,
#  "market',": 1,
#  "'Newly": 1,
#  'renovated': 1,
#  'Great': 1,
#  'Wall': 1,
#  'sections': 1,
#  'collapse': 1,
#  'rain': 1,
#  'as': 2,
#  'ancient': 1,
#  'originals': 1,
#  'stand': 1,
#  "firm',": 1,
#  "'Op-ed:": 1,
#  'Protectionism': 1,
#  'must': 1,
#  'be': 1,
#  'tackled': 1,
#  'bring': 1,
#  'orderly': 1,
#  "back',": 1,
#  '"Op-ed:': 1,
#  "Xi's": 1,
#  'Middle': 1,
#  'East,': 1,
#  'Africa': 2,
#  'visit': 1,
#  'sets': 1,
#  'South-South': 1,
#  'cooperation': 1,
#  'new': 2,
#  'journey",': 1,
#  "'PLA": 1,
#  'end': 1,
#  'commercial': 1,
#  "services',": 1,
#  "'Positive": 1,
#  'outcomes': 1,
#  'still': 1,
#  'possible': 1,
#  'suspended': 1,
#  'projects': 1,
#  'FM': 1,
#  'Wang': 1,
#  'Yi': 1,
#  'heads': 1,
#  'Malaysia:': 1,
#  "expert',": 1,
#  "'Serena": 1,
#  'Williams': 1,
#  'experiences': 1,
#  'crushing': 1,
#  'defeat': 1,
#  'San': 1,
#  "Jose',": 1,
#  "'South": 1,
#  'introduce': 1,
#  'visa': 1,
#  'policies': 1,
#  "tourists',": 1,
#  "'Starbucks": 1,
#  'sees': 1,
#  'rare': 1,
#  'fall': 2,
#  'profits': 1,
#  'China': 1,
#  '3rd': 1,
#  "quarter',": 1,
#  "'State": 1,
#  'Council': 1,
#  'promises': 1,
#  'severe': 1,
#  'punishment': 1,
#  'substandard': 1,
#  'vaccine': 1,
#  'making,': 1,
#  'vowing': 1,
#  'institutional': 1,
#  'safeguards': 1,
#  'drug': 1,
#  "safety',": 1,
#  "'Substandard": 1,
#  'DPT': 1,
#  'vaccines': 1,
#  'Wuhan': 1,
#  'an': 1,
#  'isolated': 1,
#  'case:': 1,
#  "regulator',": 1,
#  "'Trump": 1,
#  'says': 1,
#  'could': 1,
#  'talk': 1,
#  'with': 1,
#  'Iran': 1,
#  '"pretty': 1,
#  'soon"\',': 1,
#  "'US": 1,
#  'ports': 1,
#  'into': 1,
#  'direct': 1,
#  'victim': 1,
#  "war',": 1,
#  '"Washington\'s': 1,
#  'investment': 1,
#  'Indo-Pacific': 1,
#  "won't": 1,
#  'cripple': 1,
#  'Belt': 1,
#  'and': 1,
#  'Road",': 1,
#  '"Xi': 1,
#  'requires': 1,
#  'resolute': 1,
#  'ending': 1,
#  "military's": 1,
#  'paid': 1,
#  'services",': 1,
#  "'Yangtze": 2,
#  'River': 2,
#  'Stories': 2,
#  '(8)': 1,
#  'Endangered': 1,
#  'sturgeons': 1,
#  'survive': 1,
#  'through': 1,
#  'artificial': 1,
#  "breeding',": 1,
#  '(9)': 1,
#  'Three': 1,
#  'Gorges': 1,
#  'Dam': 1,
#  'creates': 1,
#  'over': 1,
#  '1.1': 1,
#  'trillion': 1,
#  'kwh': 1,
#  'cumulative': 1,
#  'power:': 1,
#  "report',": 1,
#  '"Yunnan': 1,
#  'airline': 1,
#  'introduces': 1,
#  "'occupying": 1,
#  'seat': 1,
#  'ticket\'"]': 1}

# %%
import os
import pandas as pd

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\xuwen\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
newstopwords = ['will','with',"in","china","kong","''china's","world","china's","amid","Chinese","china's"]
stopwords.extend(newstopwords)
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'will',
#  'with',
#  'in',
#  'china',
#  'kong',
#  "''china's",
#  'world',
#  "china's",
#  'amid',
#  'will',
#  'with',
#  'in',
#  'china',
#  'kong',
#  "''china's",
#  'world',
#  "china's",
#  'amid',
#  'Chinses',
#  'will',
#  'with',
#  'in',
#  'china',
#  'kong',
#  "''china's",
#  'world',
#  "china's",
#  'amid',
#  'Chinses',
#  "china's",
#  'will',
#  'with',
#  'in',
#  'china',
#  'kong',
#  "''china's",
#  'world',
#  "china's",
#  'amid',
#  'Chiness',
#  "china's",
#  'will',
#  'with',
#  'in',
#  'china',
#  'kong',
#  "''china's",
#  'world',
#  "china's",
#  'amid',
#  'Chinese',
#  "china's"]

# %%
removestopwords=[]
for i in splitwords:
    i = i.lower() 
    if i not in stopwords:
        removestopwords.append(i)
removestopwords
# Out:
# ["['800",
#  'tourists,',
#  '30m',
#  'yuan',
#  'generated',
#  'seven',
#  'months',
#  'tourism',
#  'site',
#  "liupanshui',",
#  "'aeromexico",
#  'jetliner',
#  'hit',
#  'wind',
#  'gust',
#  'takeoff:',
#  "official',",
#  "'aeromexico",
#  'plane',
#  'crashes',
#  'north',
#  'mexico,',
#  "deaths',",
#  "'china",
#  'launches',
#  'traceability',
#  'management',
#  'platform',
#  'nev',
#  "batteries',",
#  "'china",
#  'opening',
#  'wider',
#  "world',",
#  "'china",
#  'accelerate',
#  'launch',
#  'one-stop',
#  'govt',
#  'service',
#  "platform',",
#  "'china,",
#  'malaysia',
#  'willing',
#  'deepen',
#  'friendly',
#  "cooperation',",
#  "'chinese",
#  'premier',
#  'meets',
#  'british',
#  'foreign',
#  "secretary',",
#  "'commentary:",
#  'us',
#  'fed',
#  'rate',
#  'hike,',
#  'stronger',
#  'dollar',
#  'aggravate',
#  'global',
#  'debt',
#  "risk',",
#  '"commentary:',
#  'us',
#  'stands',
#  'economic',
#  'globalization',
#  "'jealous'",
#  'mentality",',
#  "'cpc",
#  'central',
#  'committee',
#  'holds',
#  'symposium',
#  'economic',
#  "work',",
#  "'cpc",
#  'meeting',
#  'stresses',
#  'economic',
#  'stability',
#  'h2,',
#  'party',
#  "discipline',",
#  "'defense",
#  'ministry',
#  'holds',
#  'reception',
#  'celebrate',
#  'pla',
#  'founding',
#  "anniversary',",
#  "'despondency",
#  'disappears',
#  'baichehe',
#  "village',",
#  '"editorial:',
#  "us'",
#  '4.1',
#  '%',
#  'growth',
#  'far',
#  'trade',
#  'war',
#  'weapon",',
#  "'editorial:",
#  'trade',
#  'war',
#  'goes',
#  "us',",
#  '"eu-us',
#  'trade',
#  'truce',
#  "can't",
#  'hide',
#  'deep',
#  'divergence",',
#  "'five",
#  'things',
#  'liupanshui,',
#  'guizhou',
#  "province',",
#  "'government",
#  'help',
#  '120,000',
#  'chinese',
#  'veterans',
#  'get',
#  'jobs',
#  "2018',",
#  "'i",
#  "xinjianger',",
#  "'liushen",
#  'florida',
#  'water',
#  'hit',
#  'african',
#  "market',",
#  "'newly",
#  'renovated',
#  'great',
#  'wall',
#  'sections',
#  'collapse',
#  'rain',
#  'ancient',
#  'originals',
#  'stand',
#  "firm',",
#  "'op-ed:",
#  'protectionism',
#  'must',
#  'tackled',
#  'bring',
#  'orderly',
#  'global',
#  'trade',
#  "back',",
#  '"op-ed:',
#  "xi's",
#  'middle',
#  'east,',
#  'africa',
#  'visit',
#  'sets',
#  'south-south',
#  'cooperation',
#  'new',
#  'journey",',
#  "'pla",
#  'end',
#  'commercial',
#  "services',",
#  "'positive",
#  'outcomes',
#  'still',
#  'possible',
#  'suspended',
#  'projects',
#  'chinese',
#  'fm',
#  'wang',
#  'yi',
#  'heads',
#  'malaysia:',
#  "expert',",
#  "'serena",
#  'williams',
#  'experiences',
#  'crushing',
#  'defeat',
#  'san',
#  "jose',",
#  "'south",
#  'africa',
#  'introduce',
#  'new',
#  'visa',
#  'policies',
#  'chinese',
#  "tourists',",
#  "'starbucks",
#  'sees',
#  'rare',
#  'fall',
#  'profits',
#  '3rd',
#  "quarter',",
#  "'state",
#  'council',
#  'promises',
#  'severe',
#  'punishment',
#  'substandard',
#  'vaccine',
#  'making,',
#  'vowing',
#  'institutional',
#  'safeguards',
#  'drug',
#  "safety',",
#  "'substandard",
#  'dpt',
#  'vaccines',
#  'wuhan',
#  'isolated',
#  'case:',
#  "regulator',",
#  "'trump",
#  'says',
#  'could',
#  'talk',
#  'iran',
#  '"pretty',
#  'soon"\',',
#  "'us",
#  'ports',
#  'fall',
#  'direct',
#  'victim',
#  'trade',
#  "war',",
#  '"washington\'s',
#  'investment',
#  'indo-pacific',
#  'cripple',
#  'belt',
#  'road",',
#  '"xi',
#  'requires',
#  'resolute',
#  'ending',
#  "military's",
#  'paid',
#  'services",',
#  "'yangtze",
#  'river',
#  'stories',
#  '(8)',
#  'endangered',
#  'chinese',
#  'sturgeons',
#  'survive',
#  'artificial',
#  "breeding',",
#  "'yangtze",
#  'river',
#  'stories',
#  '(9)',
#  'three',
#  'gorges',
#  'dam',
#  'creates',
#  '1.1',
#  'trillion',
#  'kwh',
#  'cumulative',
#  'power:',
#  "report',",
#  '"yunnan',
#  'airline',
#  'introduces',
#  "'occupying",
#  'seat',
#  'ticket\'"]']

# %%
for i in '’':#把那些乱七八糟的符号都去掉）
            removestopwords = [item.replace(i," ") for item in removestopwords]
removestopwords
# Out:
# ["['800",
#  'tourists,',
#  '30m',
#  'yuan',
#  'generated',
#  'seven',
#  'months',
#  'tourism',
#  'site',
#  "liupanshui',",
#  "'aeromexico",
#  'jetliner',
#  'hit',
#  'wind',
#  'gust',
#  'takeoff:',
#  "official',",
#  "'aeromexico",
#  'plane',
#  'crashes',
#  'north',
#  'mexico,',
#  "deaths',",
#  "'china",
#  'launches',
#  'traceability',
#  'management',
#  'platform',
#  'nev',
#  "batteries',",
#  "'china",
#  'opening',
#  'wider',
#  "world',",
#  "'china",
#  'accelerate',
#  'launch',
#  'one-stop',
#  'govt',
#  'service',
#  "platform',",
#  "'china,",
#  'malaysia',
#  'willing',
#  'deepen',
#  'friendly',
#  "cooperation',",
#  "'chinese",
#  'premier',
#  'meets',
#  'british',
#  'foreign',
#  "secretary',",
#  "'commentary:",
#  'us',
#  'fed',
#  'rate',
#  'hike,',
#  'stronger',
#  'dollar',
#  'aggravate',
#  'global',
#  'debt',
#  "risk',",
#  '"commentary:',
#  'us',
#  'stands',
#  'economic',
#  'globalization',
#  "'jealous'",
#  'mentality",',
#  "'cpc",
#  'central',
#  'committee',
#  'holds',
#  'symposium',
#  'economic',
#  "work',",
#  "'cpc",
#  'meeting',
#  'stresses',
#  'economic',
#  'stability',
#  'h2,',
#  'party',
#  "discipline',",
#  "'defense",
#  'ministry',
#  'holds',
#  'reception',
#  'celebrate',
#  'pla',
#  'founding',
#  "anniversary',",
#  "'despondency",
#  'disappears',
#  'baichehe',
#  "village',",
#  '"editorial:',
#  "us'",
#  '4.1',
#  '%',
#  'growth',
#  'far',
#  'trade',
#  'war',
#  'weapon",',
#  "'editorial:",
#  'trade',
#  'war',
#  'goes',
#  "us',",
#  '"eu-us',
#  'trade',
#  'truce',
#  "can't",
#  'hide',
#  'deep',
#  'divergence",',
#  "'five",
#  'things',
#  'liupanshui,',
#  'guizhou',
#  "province',",
#  "'government",
#  'help',
#  '120,000',
#  'chinese',
#  'veterans',
#  'get',
#  'jobs',
#  "2018',",
#  "'i",
#  "xinjianger',",
#  "'liushen",
#  'florida',
#  'water',
#  'hit',
#  'african',
#  "market',",
#  "'newly",
#  'renovated',
#  'great',
#  'wall',
#  'sections',
#  'collapse',
#  'rain',
#  'ancient',
#  'originals',
#  'stand',
#  "firm',",
#  "'op-ed:",
#  'protectionism',
#  'must',
#  'tackled',
#  'bring',
#  'orderly',
#  'global',
#  'trade',
#  "back',",
#  '"op-ed:',
#  "xi's",
#  'middle',
#  'east,',
#  'africa',
#  'visit',
#  'sets',
#  'south-south',
#  'cooperation',
#  'new',
#  'journey",',
#  "'pla",
#  'end',
#  'commercial',
#  "services',",
#  "'positive",
#  'outcomes',
#  'still',
#  'possible',
#  'suspended',
#  'projects',
#  'chinese',
#  'fm',
#  'wang',
#  'yi',
#  'heads',
#  'malaysia:',
#  "expert',",
#  "'serena",
#  'williams',
#  'experiences',
#  'crushing',
#  'defeat',
#  'san',
#  "jose',",
#  "'south",
#  'africa',
#  'introduce',
#  'new',
#  'visa',
#  'policies',
#  'chinese',
#  "tourists',",
#  "'starbucks",
#  'sees',
#  'rare',
#  'fall',
#  'profits',
#  '3rd',
#  "quarter',",
#  "'state",
#  'council',
#  'promises',
#  'severe',
#  'punishment',
#  'substandard',
#  'vaccine',
#  'making,',
#  'vowing',
#  'institutional',
#  'safeguards',
#  'drug',
#  "safety',",
#  "'substandard",
#  'dpt',
#  'vaccines',
#  'wuhan',
#  'isolated',
#  'case:',
#  "regulator',",
#  "'trump",
#  'says',
#  'could',
#  'talk',
#  'iran',
#  '"pretty',
#  'soon"\',',
#  "'us",
#  'ports',
#  'fall',
#  'direct',
#  'victim',
#  'trade',
#  "war',",
#  '"washington\'s',
#  'investment',
#  'indo-pacific',
#  'cripple',
#  'belt',
#  'road",',
#  '"xi',
#  'requires',
#  'resolute',
#  'ending',
#  "military's",
#  'paid',
#  'services",',
#  "'yangtze",
#  'river',
#  'stories',
#  '(8)',
#  'endangered',
#  'chinese',
#  'sturgeons',
#  'survive',
#  'artificial',
#  "breeding',",
#  "'yangtze",
#  'river',
#  'stories',
#  '(9)',
#  'three',
#  'gorges',
#  'dam',
#  'creates',
#  '1.1',
#  'trillion',
#  'kwh',
#  'cumulative',
#  'power:',
#  "report',",
#  '"yunnan',
#  'airline',
#  'introduces',
#  "'occupying",
#  'seat',
#  'ticket\'"]']

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
def word_count(processed_word_list):
    word_count = pd.Series(processed_word_list).value_counts().sort_values(ascending=False)[0:25]  
    fig = plt.figure(figsize=(16,8))  
    x = word_count.index.tolist()  
    y = word_count.values.tolist()  
    sns.barplot(x, y, palette="BuPu_r")  
    plt.title('people daily word frequency top 25')  
    plt.ylabel('count')  
    sns.despine(bottom=True)  
    #plt.savefig('./word_count_bar.png',dpi=400)  
    plt.show()

word_count(removestopwords)

# %%
from PIL import Image
import wordcloud
import numpy as np

def tag_cloud(text):
    mask = np.array(Image.open('picture.jpg')) #set mask, you can change to the picture you like, but it must have a high color contrast
    wc = wordcloud.WordCloud(mode='RGBA',background_color='white',max_words=2000,stopwords=stopwords,max_font_size=300,random_state=42,mask=mask)
    wc.generate_from_text(' '.join(text))
    plt.figure(figsize=(12,12))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.title('People Daily, 20180801', loc='Center', fontsize=20)
    plt.show()
    return plt.show()

tag_cloud(removestopwords)

# %%
help(set)
# Out:
# Help on class set in module builtins:
#
# class set(object)
#  |  set() -> new empty set object
#  |  set(iterable) -> new set object
#  |
#  |  Build an unordered collection of unique elements.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iand__(self, value, /)
#  |      Return self&=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __isub__(self, value, /)
#  |      Return self-=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __ixor__(self, value, /)
#  |      Return self^=value.
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __sizeof__(...)
#  |      S.__sizeof__() -> size of S in memory, in bytes
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  add(...)
#  |      Add an element to a set.
#  |
#  |      This has no effect if the element is already present.
#  |
#  |  clear(...)
#  |      Remove all elements from this set.
#  |
#  |  copy(...)
#  |      Return a shallow copy of a set.
#  |
#  |  difference(...)
#  |      Return the difference of two or more sets as a new set.
#  |
#  |      (i.e. all elements that are in this set but not the others.)
#  |
#  |  difference_update(...)
#  |      Remove all elements of another set from this set.
#  |
#  |  discard(...)
#  |      Remove an element from a set if it is a member.
#  |
#  |      If the element is not a member, do nothing.
#  |
#  |  intersection(...)
#  |      Return the intersection of two sets as a new set.
#  |
#  |      (i.e. all elements that are in both sets.)
#  |
#  |  intersection_update(...)
#  |      Update a set with the intersection of itself and another.
#  |
#  |  isdisjoint(...)
#  |      Return True if two sets have a null intersection.
#  |
#  |  issubset(...)
#  |      Report whether another set contains this set.
#  |
#  |  issuperset(...)
#  |      Report whether this set contains another set.
#  |
#  |  pop(...)
#  |      Remove and return an arbitrary set element.
#  |      Raises KeyError if the set is empty.
#  |
#  |  remove(...)
#  |      Remove an element from a set; it must be a member.
#  |
#  |      If the element is not a member, raise a KeyError.
#  |
#  |  symmetric_difference(...)
#  |      Return the symmetric difference of two sets as a new set.
#  |
#  |      (i.e. all elements that are in exactly one of the sets.)
#  |
#  |  symmetric_difference_update(...)
#  |      Update a set with the symmetric difference of itself and another.
#  |
#  |  union(...)
#  |      Return the union of sets as a new set.
#  |
#  |      (i.e. all elements that are in either set.)
#  |
#  |  update(...)
#  |      Update a set with the union of itself and others.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None
