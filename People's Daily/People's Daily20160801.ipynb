# %%
root_url="https://search-proquest-com.lib-ezproxy.hkbu.edu.hk/asianews/publication/2032725/citation/21BC158E17A64F27PQ/4?accountid=11440"

# %%
from selenium import webdriver
browser = webdriver.Chrome()

# %%
browser.get(root_url)

# %%
browser.find_element_by_css_selector('#filteryear2016').click()

# %%
browser.find_element_by_css_selector('#filtermonth082016').click()

# %%
url=browser.find_element_by_id("filterissueNameAug1,2016August").get_attribute("href")

# %%
browser.get(url)

# %%
items = browser.find_elements_by_class_name('resultItem')

# %%
data = []
for item in items:
    title = item.find_element_by_class_name('truncatedResultsTitle').text
    titleAuthorETC0 = item.find_elements_by_class_name('titleAuthorETC')[0].text
    titleAuthorETC1 = item.find_elements_by_class_name('titleAuthorETC')[1].text
    data.append((title, titleAuthorETC0, titleAuthorETC1))

# %%
data
# Out:
# [('Beijing launches worldwide open call for 2022 Winter Olympics logo',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2016."),
#  ("China's Chang'e-3 confirms lack of water in moon's Mare Imbrium",
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2016."),
#  ('Chinese Mainland tourist arrested in LA airport for slapping saleswoman',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2016."),
#  ('A glimpse of Stride 2016 Zhurihe B military drill',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2016."),
#  ('Live-streaming industry booms in China',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2016."),
#  ('Outlook for India-China cooperation on Belt and Road optimistic, says director of The Hindu',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2016."),
#  ('Rio Olympic Line begins operation, all trains made in China',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2016."),
#  ('Yahoo VP: Chinese entrepreneurs deserve special credit for efficient globalization',
#   '',
#   "People's Daily; Beijing [Beijing]01 Aug 2016.")]

# %%
import pandas as pd

# %%
df = pd.DataFrame(data, columns=['title', 'tae0', 'tae1'])

# %%
titlewords=df["title"].tolist()
titlewords
str(titlewords)
splitwords=str(titlewords).split()

# %%
words_list = splitwords #the list of words you have
dict_words_frequency={}
for n in words_list:
    dict_words_frequency[n]=words_list.count(n)
#dict_words_frequency
dict_words_frequency
# Out:
# {"['Beijing": 1,
#  'launches': 1,
#  'worldwide': 1,
#  'open': 1,
#  'call': 1,
#  'for': 4,
#  '2022': 1,
#  'Winter': 1,
#  'Olympics': 1,
#  "logo',": 1,
#  '"China\'s': 1,
#  "Chang'e-3": 1,
#  'confirms': 1,
#  'lack': 1,
#  'of': 3,
#  'water': 1,
#  'in': 4,
#  "moon's": 1,
#  'Mare': 1,
#  'Imbrium",': 1,
#  "'Chinese": 1,
#  'Mainland': 1,
#  'tourist': 1,
#  'arrested': 1,
#  'LA': 1,
#  'airport': 1,
#  'slapping': 1,
#  "saleswoman',": 1,
#  "'A": 1,
#  'glimpse': 1,
#  'Stride': 1,
#  '2016': 1,
#  'Zhurihe': 1,
#  'B': 1,
#  'military': 1,
#  "drill',": 1,
#  "'Live-streaming": 1,
#  'industry': 1,
#  'booms': 1,
#  "China',": 2,
#  "'Outlook": 1,
#  'India-China': 1,
#  'cooperation': 1,
#  'on': 1,
#  'Belt': 1,
#  'and': 1,
#  'Road': 1,
#  'optimistic,': 1,
#  'says': 1,
#  'director': 1,
#  'The': 1,
#  "Hindu',": 1,
#  "'Rio": 1,
#  'Olympic': 1,
#  'Line': 1,
#  'begins': 1,
#  'operation,': 1,
#  'all': 1,
#  'trains': 1,
#  'made': 1,
#  "'Yahoo": 1,
#  'VP:': 1,
#  'Chinese': 1,
#  'entrepreneurs': 1,
#  'deserve': 1,
#  'special': 1,
#  'credit': 1,
#  'efficient': 1,
#  "globalization']": 1}

# %%
import os
import pandas as pd

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\xuwen\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
newstopwords = ["china","kong","''china's","world","china's","amid","Chinese","china's","us","'china","says","china '"]
stopwords.extend(newstopwords)
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'china',
#  'kong',
#  "''china's",
#  'world',
#  "china's",
#  'amid',
#  'Chinese',
#  "china's",
#  'us',
#  "'china",
#  'china',
#  'kong',
#  "''china's",
#  'world',
#  "china's",
#  'amid',
#  'Chinese',
#  "china's",
#  'us',
#  "'china",
#  'says',
#  "china'",
#  'china',
#  'kong',
#  "''china's",
#  'world',
#  "china's",
#  'amid',
#  'Chinese',
#  "china's",
#  'us',
#  "'china",
#  'says',
#  "china '"]

# %%
removestopwords=[]
for i in splitwords:
    i = i.lower() 
    if i not in stopwords:
        removestopwords.append(i)
removestopwords
# Out:
# ["['beijing",
#  'launches',
#  'worldwide',
#  'open',
#  'call',
#  '2022',
#  'winter',
#  'olympics',
#  "logo',",
#  '"china\'s',
#  "chang'e-3",
#  'confirms',
#  'lack',
#  'water',
#  "moon's",
#  'mare',
#  'imbrium",',
#  "'chinese",
#  'mainland',
#  'tourist',
#  'arrested',
#  'la',
#  'airport',
#  'slapping',
#  "saleswoman',",
#  "'a",
#  'glimpse',
#  'stride',
#  '2016',
#  'zhurihe',
#  'b',
#  'military',
#  "drill',",
#  "'live-streaming",
#  'industry',
#  'booms',
#  "china',",
#  "'outlook",
#  'india-china',
#  'cooperation',
#  'belt',
#  'road',
#  'optimistic,',
#  'director',
#  "hindu',",
#  "'rio",
#  'olympic',
#  'line',
#  'begins',
#  'operation,',
#  'trains',
#  'made',
#  "china',",
#  "'yahoo",
#  'vp:',
#  'chinese',
#  'entrepreneurs',
#  'deserve',
#  'special',
#  'credit',
#  'efficient',
#  "globalization']"]

# %%
for i in '’':#把那些乱七八糟的符号都去掉）
            removestopwords = [item.replace(i," ") for item in removestopwords]
removestopwords
# Out:
# ["['beijing",
#  'launches',
#  'worldwide',
#  'open',
#  'call',
#  '2022',
#  'winter',
#  'olympics',
#  "logo',",
#  '"china\'s',
#  "chang'e-3",
#  'confirms',
#  'lack',
#  'water',
#  "moon's",
#  'mare',
#  'imbrium",',
#  "'chinese",
#  'mainland',
#  'tourist',
#  'arrested',
#  'la',
#  'airport',
#  'slapping',
#  "saleswoman',",
#  "'a",
#  'glimpse',
#  'stride',
#  '2016',
#  'zhurihe',
#  'b',
#  'military',
#  "drill',",
#  "'live-streaming",
#  'industry',
#  'booms',
#  "china',",
#  "'outlook",
#  'india-china',
#  'cooperation',
#  'belt',
#  'road',
#  'optimistic,',
#  'director',
#  "hindu',",
#  "'rio",
#  'olympic',
#  'line',
#  'begins',
#  'operation,',
#  'trains',
#  'made',
#  "china',",
#  "'yahoo",
#  'vp:',
#  'chinese',
#  'entrepreneurs',
#  'deserve',
#  'special',
#  'credit',
#  'efficient',
#  "globalization']"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
def word_count(processed_word_list):
    word_count = pd.Series(processed_word_list).value_counts().sort_values(ascending=False)[0:25]  
    fig = plt.figure(figsize=(16,8))  
    x = word_count.index.tolist()  
    y = word_count.values.tolist()  
    sns.barplot(x, y, palette="BuPu_r")  
    plt.title('people daily word frequency top 25')  
    plt.ylabel('count')  
    sns.despine(bottom=True)  
    #plt.savefig('./word_count_bar.png',dpi=400)  
    plt.show()

word_count(removestopwords)

# %%
from PIL import Image
import wordcloud
import numpy as np

def tag_cloud(text):
    mask = np.array(Image.open('picture.jpg')) #set mask, you can change to the picture you like, but it must have a high color contrast
    wc = wordcloud.WordCloud(mode='RGBA',background_color='white',max_words=2000,stopwords=stopwords,max_font_size=300,random_state=42,mask=mask)
    wc.generate_from_text(' '.join(text))
    plt.figure(figsize=(12,12))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.title('People Daily, 20160801', loc='Center', fontsize=20)
    plt.show()
    return plt.show()

tag_cloud(removestopwords)
