2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct8,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct9,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct10,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct11,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct12,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct13,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct14,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct15,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct16,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct17,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct18,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct19,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct20,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct21,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct22,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct23,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct24,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct25,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct26,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct27,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct28,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct29,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct30,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth102016","filterissueNameOct31,2016October"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov1,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov2,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov3,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov4,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov5,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov6,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov7,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov8,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov9,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov10,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov11,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov12,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov13,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov14,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov15,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov16,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov17,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov18,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov19,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov20,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov21,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov22,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov23,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov24,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov25,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov26,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov27,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov28,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov29,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth112016","filterissueNameNov30,2016November"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec1,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec2,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec3,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec4,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec5,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec6,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec7,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec8,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec9,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec10,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec11,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec12,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec13,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec14,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec15,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec16,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec17,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec18,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec19,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec20,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec21,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec22,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec23,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec24,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec25,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec26,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec27,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec28,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec29,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec30,2016December"],
    ["filterdecade2010-2019","filteryear20162010-2018","filtermonth122016","filterissueNameDec31,2016December"],
]

# %%
month = [
    ['Jan','January'],
    ['Feb','February'],
    ['Mar','March'],
    ['Apr','April'],
    ['May','May'],
    ['Jun','June'],
    ['Jul','July'],
    ['Aug','August'],
    ['Sep','September'],
    ['Oct','October'],
    ['Nov','November'],
    ['Dec','December']
]

# %%
pages = []
for i in range(2011,2012):
    a = 'filterdecade2010-2019'
    b = "filteryear" + str(i) + "2010-2018"
    for n in ['01','02','03','04','05','06','07','08','09','10','11','12']:
        c = "filtermonth" + n + str(i)
        for m in range(1,32):
            d = "filterissueName" + str(month[int(n)-1][0]) + str(m) + ',' + str(i) + str(month[int(n)-1][1])
            a_page = [a,b,c,d]
            pages.append(a_page)
pages
# Out:
# [['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan1,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan2,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan3,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan4,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan5,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan6,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan7,2011January'],
#  ['filterdecade2010-2019',
#   'filteryear20112010-2018',
#   'filtermonth012011',
#   'filterissueNameJan8,2011January'],
# ...
